# %%
from sklearn import datasets
from matplotlib import pyplot as plt
from sklearn import model_selection
# %matplotlib inline

# %%
X,y = datasets.fetch_california_housing(return_X_y=True,as_frame= True)

# %%
X
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
y
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
train_x,train_y,test_x,test_y = model_selection.train_test_split(X,y,test_size = 0.2)

# %%
test_x
# Out:
# 19888    0.79300
# 2288     0.71700
# 18720    1.11400
# 15588    2.21900
# 10653    1.94400
#           ...
# 19851    0.53500
# 8479     1.57800
# 14555    2.40200
# 17321    5.00001
# 19145    1.21600
# Name: MedHouseVal, Length: 16512, dtype: float64

# %%
train_x.plot(kind ='scatter', x = 'Longitude', y = 'Latitude',alpha = 0.4,
            s=train_x["Population"]/100, label="Population",
            c=test_x, cmap=plt.get_cmap("jet"), colorbar=True,)
plt.legend()

# %%
train_x.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.118727  0.355649  -0.060357    0.003710  0.021524
# HouseAge   -0.118727  1.000000 -0.165113  -0.080418   -0.301913  0.014217
# AveRooms    0.355649 -0.165113  1.000000   0.827217   -0.073504 -0.004719
# AveBedrms  -0.060357 -0.080418  0.827217   1.000000   -0.064552 -0.005773
# Population  0.003710 -0.301913 -0.073504  -0.064552    1.000000  0.076410
# AveOccup    0.021524  0.014217 -0.004719  -0.005773    0.076410  1.000000
# Latitude   -0.082027  0.017999  0.107132   0.067471   -0.116156  0.005392
# Longitude  -0.013116 -0.116529 -0.028999   0.013113    0.108195 -0.000102
#
#             Latitude  Longitude
# MedInc     -0.082027  -0.013116
# HouseAge    0.017999  -0.116529
# AveRooms    0.107132  -0.028999
# AveBedrms   0.067471   0.013113
# Population -0.116156   0.108195
# AveOccup    0.005392  -0.000102
# Latitude    1.000000  -0.924900
# Longitude  -0.924900   1.000000
